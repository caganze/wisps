# %% [markdown]
# Midterm goal: finish with the data analysis
#
# Play with different classes of contaminants, see why they fall where they fall
#
# → start with a sample of ~300 sources, see if you need to modify your indices

# %%
import wisps
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from wisps.data_analysis import selection_criteria as sel_crt
% matplotlib inline

# %%
#load selection criteria
crts=sel_crt.crts_from_file()

# %%
#load the selector object
selector=wisps.Selector()

# %%
best_crts=['H-cont/J-Cont H_2O-2/J-Cont', 
           'CH_4/H-Cont H_2O-2/J-Cont',
           'CH_4/H-Cont H-cont/J-Cont',
          'CH_4/H_2O-1 H_2O-2/J-Cont', 
           'CH_4/J-Cont H-cont/J-Cont']

# %%
best=[crts[x] for x in best_crts]

# %%
#see which M7-L0 are selected in all these criteria
#slctd=selector.select('T5-T9', [x for x in best], df, logic='and')

# %%
#selected=[['a'], ['a', 'b'], ['a', 'b', 'c'], ['a', 'b', 'c', 'd', 'e']]
#set().union(*selected)

# %%
#list(set.intersection(*map(set,selected)))

# %%
[x.plot(figsize=(6,6), highlight=['T5-T9']) for x in best]
# Out:
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# [None, None, None, None, None]

# %%
#
df=pd.read_hdf(wisps.COMBINED_PHOTO_SPECTRO_FILE, key='all_phot_spec_data').rename(columns={'grism_id': 'Names'})
#df=wisps.COMBINED_PHOTO_SPECTRO_DATA.rename(columns={'grism_id': 'Names'})

# %%
#best

# %%
dflist=[]
for c in crts.values():
    sl1=c.select(df, shapes_to_use=['L0-L5', 'L5-T0', 'T0-T5', 'T5-T9'])
    dflist.append(pd.concat([df[df.Names.isin(x)] for x in sl1]))

# %%
#print (dflist[0].Names.values)
import functools
t_dwarfs=functools.reduce(lambda x, y: pd.merge(x, y, how = 'inner', on='Names'), dflist)

# %%
t_dwarfs.shape
# Out:
# (2315, 101)

# %%
t_dwarfs.to_pickle(wisps.OUTPUT_FILES+'/candidates_from_indices.pkl')

# %%
def plot(name):
    sp=wisps.Source(name=name, fig_size=(6,6), save=False)
    sp.plot()

# %%
#t_dwarfs[t_dwarfs.cdf_snr>10.0].Names.apply(plot)

# %%
import splat

# %%
df.Spts.apply(splat.typeToNum).plot(kind='kde')

# %%
#try to see why some t-dwarfs are not being selected 
#df.Spts
import math

# %%
df[(df.Spts.apply(splat.typeToNum)>30) & (df.cdf_snr >10.0)].Chis.apply(math.log10).plot(kind='kde')

# %%
#
sel=wisps.
# Out:
#                      Names Spts_x   Chis_x   cdf_snr_x  CH_4/H-Cont_x  \
# 0      aegis-03-G141_12960   M1.0  45889.6     14.0926       1.070521
# 1      aegis-03-G141_12960   M1.0  45889.6     14.0926       1.070521
# 2      aegis-03-G141_12960   M1.0  45889.6     14.0926       1.070521
# 3      aegis-03-G141_12960   M1.0  45889.6     14.0926       1.070521
# 4      aegis-03-G141_12960   M1.0  45889.6     14.0926       1.070521
# 5      aegis-03-G141_12960   M1.0  45889.6     14.0926       1.070521
# 6      aegis-03-G141_12960   M1.0  45889.6     14.0926       1.070521
# 7      aegis-03-G141_12960   M1.0  45889.6     14.0926       1.070521
# 8      aegis-03-G141_12960   M1.0  45889.6     14.0926       1.070521
# 9      aegis-03-G141_12960   M1.0  45889.6     14.0926       1.070521
# 10     aegis-03-G141_12960   M1.0  45889.6     14.0926       1.070521
# 11     aegis-03-G141_12960   M1.0  45889.6     14.0926       1.070521
# ...
