# %%
import numpy as np
import splat
import wisps.data_analysis as wispd
from wisps.data_analysis import selection_criteria as sel_crt
import wispshapes
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import wisps

import random

# %%
# %matplotlib inline

# %%
#use this criteria as test
test_crit=sel_crt.crts_from_file()['CH_4/H-Cont H-cont/J-Cont']

# %%
test_crit.plot(highlight=['M7-L0'])
# Out:
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none

# %%
df=test_crit.contaminants

slctd=test_crit.select(df, shapes_to_use=[ 'T5-T9'])

# %%
df2=wisps.COMBINED_PHOTO_SPECTRO_DATA
stctdf=pd.concat([df2[df2.grism_id.isin(x)] for x in slctd])

# %%
stctdf=stctdf[stctdf.cdf_snr>10.0]
len(stctdf)

# %%
def plot(name):
    sp=wisps.Source(name=name, save=True)
    sp.plot()

# %%
#stctdf.grism_id.apply(plot)
