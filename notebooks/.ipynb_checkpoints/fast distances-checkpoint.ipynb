# %%
import numpy as np
import splat.simulate as spsim
import numba
import wisps
import matplotlib.pyplot as plt
import bisect 
import emcee
from astropy.coordinates import  SkyCoord 
import astropy.units as u
import scipy.integrate as integrate

# %matplotlib inline

# %%
@numba.jit
def convert_to_rz(ra, dec, dist):
    """
    returns r and z given a distance
    """
    newcoord=SkyCoord(ra=ra, dec=dec, distance=dist*u.pc)
    r=(newcoord.cartesian.x**2+newcoord.cartesian.y**2)**0.5
    z=newcoord.cartesian.z
    return r.to(u.pc).value, z.to(u.pc).value

@numba.vectorize
def juric_density_function(r, z):
    
    """
    A custom juric density function that only uses numpy arrays for speed
    All units are in pc
    """
    ##constants
    r0 = 8000 # radial offset from galactic center to Sun
    z0 = 25.  # vertical offset from galactic plane to Sun
    l1 = 2600. # radial length scale of exponential thin disk 
    h1 = 300.# vertical length scale of exponential thin disk 
    ftd = 0.12 # relative number of thick disk to thin disk star counts
    l2 = 3600. # radial length scale of exponential thin disk 
    h2 = 900. # vertical length scale of exponential thin disk 
    fh = 0.0051 # relative number of halo to thin disk star counts
    qh = 0.64 # halo axial ratio
    nh = 2.77 # halo power law index
    
    dens0=1.0
    
    thindens=dens0*np.exp(-abs(r-r0)/l1)*np.exp(-abs(z-z0)/h1)
    thickdens=dens0*np.exp(-abs(r-r0)/l2)*np.exp(-abs(z-z0)/h2)
    halodens= dens0*(((r0/(r**2+(z/qh)**2)**0.5))**nh)
    
    return thindens+ftd*thickdens+fh*halodens


@numba.jit
def custom_volume_correction(c, dmin, dmax, nsamp=100):
    """
    A volume correction term that only uses numpy array for speed
    All units are in pc
    """
    dds = np.linspace(dmin,dmax,nsamp)
    r, z=convert_to_rz(c.ra, c.dec, dds)
    rho=juric_density_function(r, z)
    return integrate.trapz(rho*(dds**2), x=dds)/(dmax**3)

# %%
class Pointing(object):
    ## a pointing object making it easier to draw samples
    
    def __init__(self, **kwargs):
        #only input is the direction
        self.coord=kwargs.get('coord', None)
        self.ensemble_samplers=[]
    
    @numba.vectorize
    def get_cdf_point(x):
        ##get the value of the cdf at a given distance
        return custom_volume_correction(self.coord, dmin,x)
        
    def cdf(self,  dmax, dmin):
        """
        The cumulative distribution function along the line of sight
        """
        norm=6*(dmax**3)*custom_volume_correction(self.coord, dmin, 2*dmax)
        dds=np.linspace(dmin+1.0, dmax, 100000)
        return dds, [x**3*custom_volume_correction(self.coord, dmin,x)/norm for x in  dds]

    def random_draw(self,  dmax, dmin, nsample=1000):
        """
        randomly drawing x distances in a given direction
        """
        dvals, cdfvals=self.cdf(dmax, dmin)
        x=np.random.rand(nsample)
        idx=[bisect.bisect(cdfvals, i) for i in x]
        return dvals[idx]

# %%
coord=SkyCoord(ra=45*u.deg, dec=-45*u.deg)

# %%
pnt=Pointing(coord=coord)

# %%
dmin=201.0
dmax=2000.0
plt.hist(pnt.random_draw( dmax, dmin, nsample=10000))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-326-441bb8346c53> in <module>
#       1 dmin=201.0
#       2 dmax=2000.0
# ----> 3 plt.hist(pnt.random_draw( dmax, dmin, nsample=10000))
#
# <ipython-input-323-028e279bb189> in random_draw(self, dmax, dmin, nsample)
#      20         randomly drawing x distances in a given direction
#      21         """
# ---> 22         dvals, cdfvals=self.cdf(dmax, dmin)
#      23         x=np.random.rand(nsample)
#      24         idx=[bisect.bisect(cdfvals, i) for i in x]
#
# <ipython-input-323-028e279bb189> in cdf(self, dmax, dmin)
#      14         norm=6*(dmax**3)*custom_volume_correction(self.coord, dmin, 2*dmax)
#      15         dds=np.linspace(dmin+1.0, dmax, 100000)
# ---> 16         return dds, [x**3*custom_volume_correction(self.coord, dmin,x)/norm for x in  dds]
#      17
#      18     def random_draw(self,  dmax, dmin, nsample=1000):
#
# <ipython-input-323-028e279bb189> in <listcomp>(.0)
#      14         norm=6*(dmax**3)*custom_volume_correction(self.coord, dmin, 2*dmax)
#      15         dds=np.linspace(dmin+1.0, dmax, 100000)
# ---> 16         return dds, [x**3*custom_volume_correction(self.coord, dmin,x)/norm for x in  dds]
#      17
#      18     def random_draw(self,  dmax, dmin, nsample=1000):
#
# /anaconda3/lib/python3.6/site-packages/astropy/coordinates/sky_coordinate.py in __init__(self, copy, *args, **kwargs)
#     270             # Finally make the internal coordinate object.
#     271             frame_kwargs.update(components)
# --> 272             self._sky_coord_frame = frame_cls(copy=copy, **frame_kwargs)
#     273
#     274             if not self._sky_coord_frame.has_data:
#
# /anaconda3/lib/python3.6/site-packages/astropy/coordinates/baseframe.py in __init__(self, copy, representation_type, differential_type, *args, **kwargs)
#     501                 try:
#     502                     representation_data = representation_cls(copy=copy,
# --> 503                                                              **repr_kwargs)
#     504                 except TypeError as e:
#     505                     # this except clause is here to make the names of the
#
# /anaconda3/lib/python3.6/site-packages/astropy/coordinates/representation.py in __init__(self, lon, lat, distance, differentials, copy)
#    1565     def __init__(self, lon, lat, distance, differentials=None, copy=True):
#    1566         super().__init__(lon, lat, distance, copy=copy,
# -> 1567                          differentials=differentials)
#    1568         if self._distance.unit.physical_type == 'length':
#    1569             try:
#
# /anaconda3/lib/python3.6/site-packages/astropy/coordinates/representation.py in __init__(self, differentials, *args, **kwargs)
#     490     def __init__(self, *args, differentials=None, **kwargs):
#     491         # Handle any differentials passed in.
# --> 492         super().__init__(*args, **kwargs)
#     493         self._differentials = self._validate_differentials(differentials)
#     494
#
# /anaconda3/lib/python3.6/site-packages/astropy/coordinates/representation.py in __init__(self, *args, **kwargs)
#     157         # Pass attributes through the required initializing classes.
#     158         attrs = [self.attr_classes[component](attr, copy=copy)
# --> 159                  for component, attr in zip(components, attrs)]
#     160         try:
#     161             attrs = np.broadcast_arrays(*attrs, subok=True)
#
# /anaconda3/lib/python3.6/site-packages/astropy/coordinates/representation.py in <listcomp>(.0)
#     157         # Pass attributes through the required initializing classes.
#     158         attrs = [self.attr_classes[component](attr, copy=copy)
# --> 159                  for component, attr in zip(components, attrs)]
#     160         try:
#     161             attrs = np.broadcast_arrays(*attrs, subok=True)
#
# /anaconda3/lib/python3.6/site-packages/astropy/coordinates/angles.py in __new__(cls, angle, unit, wrap_angle, **kwargs)
#     616         if wrap_angle is None:
#     617             wrap_angle = getattr(angle, 'wrap_angle', self._default_wrap_angle)
# --> 618         self.wrap_angle = wrap_angle
#     619         return self
#     620
#
# /anaconda3/lib/python3.6/site-packages/astropy/coordinates/angles.py in wrap_angle(self, value)
#     652     def wrap_angle(self, value):
#     653         self._wrap_angle = Angle(value, copy=False)
# --> 654         self._wrap_internal()
#     655
#     656     def __array_finalize__(self, obj):
#
# /anaconda3/lib/python3.6/site-packages/astropy/coordinates/angles.py in _wrap_internal(self)
#     636         # than Quantity objects for speed.
#     637         a360 = u.degree.to(self.unit, 360.0)
# --> 638         wrap_angle = self.wrap_angle.to_value(self.unit)
#     639         wrap_angle_floor = wrap_angle - a360
#     640         self_angle = self.value
#
# KeyboardInterrupt:

# %%
custom_volume_correction(coord, 1.0, np.linspace(2, 200, 100), nsamp=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-328-1af480daca77> in <module>
# ----> 1 custom_volume_correction(coord, 1.0, np.linspace(2, 200, 100), nsamp=100)
#
# /anaconda3/lib/python3.6/site-packages/numpy/core/function_base.py in linspace(start, stop, num, endpoint, retstep, dtype)
#     122     if num > 1:
#     123         step = delta / div
# --> 124         if step == 0:
#     125             # Special handling for denormal numbers, gh-5437
#     126             y /= div
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
# %prun pnt.random_draw( dmax, dmin, nsample=10000)
# Out:
#          1808817 function calls (1781790 primitive calls) in 2.110 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     11011    0.073    0.000    0.073    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     31033    0.064    0.000    0.191    0.000 {built-in method numpy.core.multiarray.array}
#     10010    0.060    0.000    0.496    0.000 baseframe.py:983(represent_as)
# 96096/81081    0.055    0.000    0.177    0.000 {built-in method builtins.getattr}
#     19019    0.050    0.000    0.100    0.000 core.py:533(_get_physical_type_id)
#      1001    0.047    0.000    1.710    0.002 <ipython-input-280-78b824c4bd9d>:2(convert_to_rz)
#      1001    0.044    0.000    1.978    0.002 <ipython-input-280-78b824c4bd9d>:40(custom_volume_correction)
#    138139    0.039    0.000    0.050    0.000 {built-in method builtins.isinstance}
#     10010    0.039    0.000    0.064    0.000 baseframe.py:838(get_representation_component_names)
#     39039    0.037    0.000    0.073    0.000 {method 'view' of 'numpy.ndarray' objects}
#      2002    0.037    0.000    0.560    0.000 baseframe.py:414(__init__)
#     35035    0.034    0.000    0.218    0.000 quantity.py:392(__array_finalize__)
#      3003    0.033    0.000    0.115    0.000 stride_tricks.py:115(_broadcast_to)
#     15015    0.033    0.000    0.248    0.000 quantity.py:272(__new__)
# 69069/60060    0.032    0.000    0.471    0.000 {built-in method builtins.hasattr}
#      5005    0.029    0.000    0.029    0.000 {function Longitude.__array_ufunc__ at 0x118685c80}
#      5005    0.029    0.000    0.313    0.000 quantity.py:421(__array_ufunc__)
#      1002    0.029    0.000    0.052    0.000 function_base.py:25(linspace)
#      9009    0.029    0.000    0.071    0.000 quantity.py:532(_new_view)
#     10010    0.027    0.000    0.098    0.000 fromnumeric.py:64(_wrapreduction)
#      3003    0.025    0.000    0.054    0.000 core.py:2085(_expand_and_gather)
#      7007    0.025    0.000    0.593    0.000 sky_coordinate.py:570(__getattr__)
#     10010    0.025    0.000    0.068    0.000 baseframe.py:82(_get_repr_classes)
#     33033    0.025    0.000    0.037    0.000 decorators.py:720(__get__)
#     20020    0.024    0.000    0.039    0.000 quantity.py:673(to_value)
# 21021/18018    0.024    0.000    0.098    0.000 core.py:2132(decompose)
#      9009    0.023    0.000    0.177    0.000 core.py:781(is_equivalent)
#      2002    0.022    0.000    0.377    0.000 representation.py:132(__init__)
#      6006    0.020    0.000    0.094    0.000 core.py:2010(__init__)
#     11011    0.020    0.000    0.122    0.000 core.py:922(_to)
#      5005    0.018    0.000    0.168    0.000 converters.py:125(converters_and_unit)
#     18018    0.017    0.000    0.031    0.000 core.py:1951(decompose)
#      2002    0.016    0.000    0.147    0.000 representation.py:998(__init__)
#         1    0.016    0.016    2.098    2.098 <ipython-input-313-8e2745ee4d96>:16(<listcomp>)
#      3003    0.016    0.000    0.160    0.000 quantity.py:984(__pow__)
#      1001    0.016    0.000    0.230    0.000 sky_coordinate_parsers.py:569(_get_representation_attrs)
#      1001    0.016    0.000    0.075    0.000 distances.py:98(__new__)
#      7007    0.015    0.000    0.165    0.000 quantity.py:1591(_set_unit)
#      9009    0.015    0.000    0.036    0.000 core.py:616(_normalize_equivalencies)
#     22022    0.015    0.000    0.031    0.000 baseframe.py:704(get_representation_cls)
#      1001    0.015    0.000    0.193    0.000 representation.py:1639(to_cartesian)
#     65065    0.015    0.000    0.015    0.000 {method 'get' of 'dict' objects}
#     24024    0.015    0.000    0.022    0.000 quantity.py:594(_set_unit)
#      6006    0.014    0.000    0.122    0.000 baseframe.py:1504(__getattr__)
#      1001    0.014    0.000    0.834    0.001 sky_coordinate.py:211(__init__)
#      2002    0.013    0.000    0.084    0.000 angles.py:628(_wrap_internal)
#     14014    0.013    0.000    0.013    0.000 representation.py:225(components)
#      9009    0.012    0.000    0.109    0.000 core.py:812(_is_equivalent)
#      1001    0.012    0.000    0.038    0.000 function_base.py:3804(trapz)
#      2002    0.012    0.000    0.013    0.000 stride_tricks.py:179(_broadcast_shape)
#     10010    0.012    0.000    0.019    0.000 representation.py:174(get_name)
#     16016    0.012    0.000    0.012    0.000 _weakrefset.py:70(__contains__)
#      8008    0.012    0.000    0.020    0.000 core.py:901(<lambda>)
#      8008    0.012    0.000    0.088    0.000 core.py:955(to)
#      2002    0.012    0.000    0.073    0.000 angles.py:517(_validate_angles)
#     19019    0.011    0.000    0.017    0.000 core.py:541(<listcomp>)
#     10010    0.011    0.000    0.030    0.000 representation.py:266(shape)
#      6006    0.011    0.000    0.164    0.000 angles.py:83(__new__)
#      8008    0.011    0.000    0.056    0.000 core.py:892(_get_converter)
#     27027    0.011    0.000    0.018    0.000 core.py:1766(__call__)
#      2002    0.010    0.000    0.157    0.000 stride_tricks.py:198(broadcast_arrays)
#      9009    0.010    0.000    0.090    0.000 fromnumeric.py:1933(any)
#      1002    0.010    0.000    0.010    0.000 {built-in method numpy.core.multiarray.arange}
#      7007    0.010    0.000    0.013    0.000 baseframe.py:1547(__setattr__)
#      2002    0.010    0.000    0.189    0.000 representation.py:158(<listcomp>)
#      9009    0.010    0.000    0.010    0.000 core.py:64(_normalize_equivalencies)
#      1001    0.010    0.000    0.011    0.000 function_base.py:1079(diff)
#     10010    0.009    0.000    0.019    0.000 baseframe.py:48(_get_repr_cls)
#      6006    0.009    0.000    0.155    0.000 angles.py:130(_set_unit)
#      9009    0.009    0.000    0.009    0.000 {built-in method numpy.core.multiarray.can_cast}
#     61061    0.009    0.000    0.009    0.000 {built-in method builtins.len}
#      2002    0.008    0.000    0.018    0.000 ansitowin32.py:52(__init__)
#      9009    0.008    0.000    0.034    0.000 misc.py:916(size)
#     20020    0.008    0.000    0.008    0.000 {method 'startswith' of 'str' objects}
#      2002    0.008    0.000    0.193    0.000 angles.py:610(__new__)
#      9009    0.008    0.000    0.008    0.000 core.py:222(equivalencies)
#      8008    0.008    0.000    0.015    0.000 abc.py:196(__subclasscheck__)
#      4004    0.008    0.000    0.024    0.000 quantity.py:1027(quantity_iter)
#      1001    0.008    0.000    0.092    0.000 typeof.py:25(typeof)
#      8008    0.008    0.000    0.023    0.000 {built-in method builtins.issubclass}
#      2002    0.007    0.000    0.011    0.000 numeric.py:1468(normalize_axis_tuple)
#      1001    0.007    0.000    0.044    0.000 errors.py:202(_markup)
#      6006    0.007    0.000    0.010    0.000 utils.py:197(validate_power)
#      1001    0.007    0.000    0.444    0.000 representation.py:1565(__init__)
#      4004    0.007    0.000    0.100    0.000 angles.py:656(__array_finalize__)
#      1001    0.007    0.000    0.026    0.000 numeric.py:1524(moveaxis)
#      1001    0.007    0.000    0.014    0.000 sky_coordinate_parsers.py:62(_get_frame_without_data)
#      3003    0.007    0.000    0.036    0.000 core.py:643(__pow__)
#      6006    0.007    0.000    0.424    0.000 baseframe.py:1643(cartesian)
#      2002    0.007    0.000    0.007    0.000 helpers.py:42(<lambda>)
#      5005    0.007    0.000    0.030    0.000 quantity.py:458(<listcomp>)
#     29029    0.006    0.000    0.006    0.000 quantity.py:730(unit)
#      3003    0.006    0.000    0.011    0.000 abc.py:180(__instancecheck__)
#      2002    0.006    0.000    0.386    0.000 representation.py:490(__init__)
#      2002    0.006    0.000    0.007    0.000 baseframe.py:699(get_frame_attr_names)
#      1001    0.006    0.000    0.035    0.000 core.py:703(__rmul__)
#      8008    0.006    0.000    0.008    0.000 core.py:2319(_condition_arg)
#      2002    0.006    0.000    0.152    0.000 angles.py:509(__new__)
#     22022    0.006    0.000    0.006    0.000 core.py:1574(name)
#      1001    0.006    0.000    0.238    0.000 sky_coordinate_parsers.py:215(_parse_coordinate_data)
#      9009    0.006    0.000    0.040    0.000 misc.py:934(__bool__)
#      8008    0.006    0.000    0.010    0.000 {built-in method builtins.any}
#      2002    0.006    0.000    0.006    0.000 sky_coordinate.py:602(__setattr__)
#      1001    0.006    0.000    0.009    0.000 typeof.py:60(_typeof_buffer)
#      6006    0.005    0.000    0.012    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#      5005    0.005    0.000    0.047    0.000 quantity.py:474(_result_as_quantity)
#     10000    0.005    0.000    0.005    0.000 {built-in method _bisect.bisect}
#      6006    0.005    0.000    0.009    0.000 {built-in method builtins.all}
#      3003    0.005    0.000    0.072    0.000 stride_tricks.py:25(_maybe_view_as_subclass)
#      5005    0.005    0.000    0.007    0.000 <frozen importlib._bootstrap>:416(parent)
#      2002    0.005    0.000    0.023    0.000 initialise.py:74(wrap_stream)
#      2002    0.005    0.000    0.066    0.000 quantity.py:638(_to_value)
#     25025    0.005    0.000    0.005    0.000 core.py:2071(bases)
#      1001    0.005    0.000    0.028    0.000 erfa.py:25(helper_s2p)
#      2002    0.005    0.000    0.094    0.000 angles.py:651(wrap_angle)
#      1001    0.004    0.000    0.032    0.000 typeof.py:39(typeof_impl)
#      2002    0.004    0.000    0.089    0.000 quantity.py:645(to)
#      1001    0.004    0.000    0.017    0.000 core.py:1333(physical_type)
#      1001    0.004    0.000    0.091    0.000 angles.py:662(__array_ufunc__)
#     24024    0.004    0.000    0.004    0.000 {method 'items' of 'dict' objects}
#      6006    0.004    0.000    0.004    0.000 {built-in method builtins.setattr}
#      3003    0.004    0.000    0.007    0.000 core.py:2041(<listcomp>)
#      2003    0.004    0.000    0.004    0.000 {built-in method numpy.core.multiarray.result_type}
#     11011    0.004    0.000    0.004    0.000 baseframe.py:660(data)
#      1001    0.004    0.000    0.096    0.000 dispatcher.py:485(typeof_pyval)
#     10010    0.004    0.000    0.004    0.000 {method 'endswith' of 'str' objects}
#      1001    0.004    0.000    0.119    0.000 stride_tricks.py:260(<listcomp>)
#     17017    0.004    0.000    0.004    0.000 {method 'pop' of 'dict' objects}
#     12012    0.004    0.000    0.004    0.000 transformations.py:111(frame_attributes)
#      9009    0.004    0.000    0.005    0.000 core.py:1672(decompose)
#      6006    0.004    0.000    0.004    0.000 utils.py:251(resolve_fractions)
#      3003    0.004    0.000    0.009    0.000 {method 'sort' of 'list' objects}
#     22022    0.004    0.000    0.004    0.000 core.py:2078(powers)
#      5005    0.004    0.000    0.010    0.000 converters.py:163(<listcomp>)
#      6006    0.004    0.000    0.006    0.000 utils.py:173(sanitize_scale)
#      1001    0.004    0.000    0.009    0.000 converters.py:269(check_output)
#      1001    0.004    0.000    0.197    0.000 representation.py:663(represent_as)
#      1001    0.004    0.000    0.209    0.000 representation.py:1625(represent_as)
#      3003    0.003    0.000    0.005    0.000 core.py:2086(add_unit)
#     11011    0.003    0.000    0.008    0.000 representation.py:408(get_component)
#      3003    0.003    0.000    0.085    0.000 helpers.py:28(get_converter)
#      1001    0.003    0.000    0.026    0.000 initialise.py:23(init)
#      9009    0.003    0.000    0.003    0.000 core.py:281(get_current_unit_registry)
#      6006    0.003    0.000    0.003    0.000 {method 'pop' of 'list' objects}
#      1001    0.003    0.000    0.004    0.000 api.py:185(typeof)
#         1    0.003    0.003    0.008    0.008 <ipython-input-313-8e2745ee4d96>:24(<listcomp>)
#      2002    0.003    0.000    0.004    0.000 baseframe.py:781(_get_representation_info)
#     13013    0.003    0.000    0.003    0.000 converters.py:168(<genexpr>)
#      3003    0.003    0.000    0.003    0.000 representation.py:495(_validate_differentials)
#      1001    0.003    0.000    0.007    0.000 cffi_utils.py:37(is_cffi_func)
#      2002    0.003    0.000    0.003    0.000 {method 'format' of 'str' objects}
#      2002    0.003    0.000    0.010    0.000 stride_tricks.py:250(<listcomp>)
#     10010    0.002    0.000    0.002    0.000 {method 'lower' of 'str' objects}
#     11011    0.002    0.000    0.002    0.000 core.py:581(bases)
#      2002    0.002    0.000    0.027    0.000 helpers.py:103(helper_square)
#      6006    0.002    0.000    0.002    0.000 utils.py:163(is_effectively_unity)
#     11011    0.002    0.000    0.002    0.000 representation.py:570(differentials)
#      6006    0.002    0.000    0.002    0.000 angles.py:126(_convert_unit_to_angle_unit)
#      6006    0.002    0.000    0.002    0.000 stride_tricks.py:254(<genexpr>)
#      8008    0.002    0.000    0.002    0.000 core.py:948(<genexpr>)
#     11011    0.002    0.000    0.002    0.000 core.py:588(powers)
#      8008    0.002    0.000    0.002    0.000 {method 'item' of 'numpy.ndarray' objects}
#      3003    0.002    0.000    0.007    0.000 core.py:2023(<listcomp>)
#      5005    0.002    0.000    0.002    0.000 {method 'rpartition' of 'str' objects}
#      1001    0.002    0.000    0.002    0.000 errors.py:150(__exit__)
#      1001    0.002    0.000    0.005    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#      1002    0.002    0.000    0.002    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      5007    0.002    0.000    0.008    0.000 numeric.py:504(asanyarray)
#      2002    0.002    0.000    0.003    0.000 transformations.py:422(lookup_name)
#      1001    0.002    0.000    0.021    0.000 fromnumeric.py:1821(sum)
#     11011    0.002    0.000    0.002    0.000 {method 'keys' of 'collections.OrderedDict' objects}
#      1001    0.002    0.000    0.002    0.000 {built-in method numpy.core.multiarray.empty}
#      1001    0.002    0.000    0.037    0.000 functools.py:802(wrapper)
#      7007    0.002    0.000    0.002    0.000 sky_coordinate.py:277(frame)
#      6006    0.002    0.000    0.002    0.000 core.py:734(__hash__)
#      3003    0.002    0.000    0.003    0.000 function_base.py:241(iterable)
#      1001    0.002    0.000    0.003    0.000 functools.py:764(dispatch)
#     10010    0.002    0.000    0.002    0.000 core.py:2064(scale)
#      3003    0.002    0.000    0.005    0.000 core.py:2120(<lambda>)
#      7007    0.002    0.000    0.002    0.000 quantity.py:514(__quantity_subclass__)
#      1001    0.002    0.000    0.002    0.000 errors.py:144(__init__)
#      3003    0.002    0.000    0.002    0.000 {built-in method numpy.core.multiarray.normalize_axis_index}
#      1001    0.002    0.000    0.028    0.000 errors.py:131(__init__)
#      1001    0.002    0.000    0.065    0.000 helpers.py:45(get_converters_and_unit)
#      8008    0.002    0.000    0.002    0.000 representation.py:1586(lon)
#      3003    0.002    0.000    0.002    0.000 core.py:2119(<listcomp>)
#      4004    0.002    0.000    0.005    0.000 baseframe.py:1080(<genexpr>)
#      6006    0.002    0.000    0.002    0.000 stride_tricks.py:120(<genexpr>)
#      6006    0.002    0.000    0.002    0.000 iostream.py:316(closed)
#      1001    0.002    0.000    0.009    0.000 physical.py:48(get_physical_type)
#      1001    0.001    0.000    0.001    0.000 {built-in method builtins.sorted}
#      1001    0.001    0.000    0.002    0.000 quantity.py:1020(__iter__)
#      2002    0.001    0.000    0.006    0.000 baseframe.py:830(representation_info)
#      4004    0.001    0.000    0.002    0.000 numeric.py:1515(<genexpr>)
#      1001    0.001    0.000    0.012    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      3003    0.001    0.000    0.001    0.000 {method 'encode' of 'str' objects}
#      4004    0.001    0.000    0.003    0.000 baseframe.py:302(getter)
#      2002    0.001    0.000    0.004    0.000 ansitowin32.py:16(is_stream_closed)
#      2002    0.001    0.000    0.003    0.000 ansitowin32.py:20(is_a_tty)
#      1001    0.001    0.000    0.046    0.000 errors.py:217(errmsg)
#      1001    0.001    0.000    0.001    0.000 weakref.py:393(__getitem__)
#      1001    0.001    0.000    0.001    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      3003    0.001    0.000    0.001    0.000 core.py:1957(__hash__)
#      1001    0.001    0.000    0.013    0.000 helpers.py:115(helper_sqrt)
#      2002    0.001    0.000    0.001    0.000 ansitowin32.py:95(get_win32_calls)
#      7007    0.001    0.000    0.001    0.000 {method 'items' of 'collections.OrderedDict' objects}
#      1001    0.001    0.000    0.001    0.000 cffi_utils.py:27(is_ffi_instance)
#      4004    0.001    0.000    0.001    0.000 angles.py:647(wrap_angle)
#      1001    0.001    0.000    0.001    0.000 baseframe.py:638(cache)
#      2002    0.001    0.000    0.001    0.000 ansitowin32.py:30(__init__)
#      1002    0.001    0.000    0.001    0.000 numeric.py:1927(isscalar)
#      1001    0.001    0.000    0.001    0.000 {method 'decode' of 'bytearray' objects}
#      2002    0.001    0.000    0.001    0.000 {method 'isatty' of '_io._IOBase' objects}
#      1001    0.001    0.000    0.002    0.000 baseframe.py:755(differential_type)
#      3003    0.001    0.000    0.001    0.000 core.py:2122(<listcomp>)
#      1001    0.001    0.000    0.002    0.000 <string>:12(__new__)
#      2002    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#      1001    0.001    0.000    0.001    0.000 errors.py:135(__enter__)
#      1001    0.001    0.000    0.001    0.000 errors.py:139(__exit__)
#      1002    0.001    0.000    0.001    0.000 function_base.py:13(_index_deprecate)
#      3003    0.001    0.000    0.001    0.000 baseframe.py:130(_normalize_representation_type)
#      1001    0.001    0.000    0.001    0.000 angles.py:451(_no_angle_subclass)
#      6006    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#      2002    0.001    0.000    0.001    0.000 representation.py:47(get_reprdiff_cls_hash)
#      3003    0.001    0.000    0.001    0.000 {built-in method _operator.mul}
#      3003    0.001    0.000    0.001    0.000 {built-in method builtins.iter}
#      2002    0.001    0.000    0.001    0.000 transformations.py:86(_cached_names)
#      1001    0.001    0.000    0.011    0.000 _methods.py:34(_sum)
#      4004    0.001    0.000    0.001    0.000 core.py:574(scale)
#      3003    0.001    0.000    0.001    0.000 core.py:2123(<listcomp>)
#      1001    0.001    0.000    0.001    0.000 inspect.py:73(isclass)
#      1001    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x104cb0dd8}
#      1001    0.001    0.000    0.001    0.000 numeric.py:1586(<listcomp>)
#      1001    0.001    0.000    0.001    0.000 sky_coordinate_parsers.py:332(_get_representation_component_units)
#      1001    0.001    0.000    0.001    0.000 initialise.py:67(reinit)
#      2002    0.001    0.000    0.001    0.000 baseframe.py:701(<genexpr>)
#      3004    0.001    0.000    0.001    0.000 {built-in method _operator.index}
#      3003    0.001    0.000    0.001    0.000 representation.py:1593(lat)
#         1    0.001    0.001    2.110    2.110 <ipython-input-313-8e2745ee4d96>:18(random_draw)
#      1001    0.001    0.000    0.001    0.000 distances.py:123(<listcomp>)
#      1001    0.001    0.000    0.001    0.000 initialise.py:51(deinit)
#      1001    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
#      2002    0.001    0.000    0.001    0.000 ansitowin32.py:85(should_wrap)
#      1001    0.001    0.000    0.001    0.000 quantity.py:768(isscalar)
#      1001    0.000    0.000    0.000    0.000 representation.py:615(_re_represent_differentials)
#      1001    0.000    0.000    0.000    0.000 baseframe.py:672(has_data)
#      2002    0.000    0.000    0.000    0.000 representation.py:1600(distance)
#      1001    0.000    0.000    0.000    0.000 baseframe.py:602(<dictcomp>)
#      1001    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#      1001    0.000    0.000    0.000    0.000 errors.py:147(__enter__)
#         1    0.000    0.000    0.000    0.000 {method 'rand' of 'mtrand.RandomState' objects}
#      1001    0.000    0.000    0.000    0.000 representation.py:1081(from_cartesian)
#      1001    0.000    0.000    0.000    0.000 {method 'values' of 'collections.OrderedDict' objects}
#         1    0.000    0.000    2.110    2.110 <string>:1(<module>)
#         1    0.000    0.000    2.110    2.110 {built-in method builtins.exec}
#         1    0.000    0.000    2.101    2.101 <ipython-input-313-8e2745ee4d96>:10(cdf)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
