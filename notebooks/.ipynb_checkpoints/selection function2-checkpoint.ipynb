# %%
import splat
import wisps
import matplotlib.pyplot as plt
from wisps.data_analysis import selection_criteria as sel_crt
from wisps.utils.tools import extrap1d
from wisps.simulations import selection_function as slf
import numpy as np
import pandas as pd

import matplotlib as mpl

mpl.rcParams['grid.color'] = 'k'
mpl.rcParams['grid.linestyle'] = '--'
mpl.rcParams['grid.linewidth'] = 0.1
mpl.rcParams['figure.figsize'] = [8.0, 6.0]
mpl.rcParams['figure.dpi'] = 80
mpl.rcParams['savefig.dpi'] = 100
mpl.rcParams['font.size'] = 18
mpl.rcParams['legend.fontsize'] = 'large'
mpl.rcParams['figure.titlesize'] = 'large'

# %matplotlib inline
#%%capture  output
import splat

# %%
sf=pd.read_pickle(wisps.OUTPUT_FILES+'/selection_function.pkl')

# %%
import numba

# %%
@numba.vectorize("float64(float64)")
def f_test_only(f):
    if f>0.5: return 1
    else: return 0

# %%
sf.data['selected_ftest']=f_test_only(sf.data.f.values)

# %%
@numba.vectorize("float64(float64, float64)")
def probfunction(x, y):
    return sf.probability_of_selection(x, y)


@numba.vectorize("float64(float64, float64)")
def profunctiontestonly(spt, snr):
    if snr <3: return 0
    else:
        floor=np.floor(spt)
        floor2=np.floor(snr)
        return np.nanmean(sf.data.selected_ftest[(sf.data.spt==floor) &(sf.data.snr1.between(floor2, floor2+3.0))])

# %%
sprange=np.random.uniform(19, 39, 10000)
snrrange=10**np.random.uniform(-1, 3, 10000)
vals=probfunction(sprange, snrrange)
ftestprob=profunctiontestonly(sprange, snrrange)

# %%
df=pd.DataFrame()
df['snr']=np.log10(snrrange)
df['spt']=sprange
df['prob']=vals
df['ftestprob']=ftestprob

# %%
df3=sf.data
df3['logsnr']=sf.data.snr1.apply(np.log10)

# %%
fig, ax=plt.subplots(ncols=2, figsize=(12, 4), sharex=False, sharey=True)
df.plot.hexbin(x='snr', y='spt', C='prob', reduce_C_function=np.nanmean, gridsize=10, cmap=wisps.MYCOLORMAP2, ax=ax[0])
df.plot.hexbin(x='snr', y='spt', C='ftestprob', reduce_C_function=np.nanmean, gridsize=10, cmap=wisps.MYCOLORMAP2, ax=ax[1])

#ax[0].scatter( sf.data.snr1.apply(np.log10), sf.data.spt, marker='+', color='#111111', alpha=.5)
#ax[1].scatter( sf.data.snr1.apply(np.log10), sf.data.spt, marker='+', color='#111111', alpha=.5)
ax[1].set_xlim([0, 3])
ax[0].set_xlim([0, 3])
for a in ax:
    a.set_xlabel('log SNR')
    a.set_ylabel('SpT')
    a.axvline(np.log10(3), linestyle='--', color='#111111')
    a.grid()
    a.set_xticks(np.arange(-1, 3, 0.1), minor=True)
    a.yaxis.set_ticks_position('both')
    a.xaxis.set_ticks_position('both')
    a.set_yticks(np.arange(20, 40, 1), minor=True)
    a.tick_params(which='major',direction='inout')
    a.tick_params(which='minor', direction='in')
    
plt.tight_layout()
plt.savefig(wisps.OUTPUT_FIGURES+'/selection_function_samples.pdf', bbox_inches='tight', dpi=200)

# %%
@numba.jit
def plot(s):
    xvals=np.where((s.wave>0.8) & (s.wave<2.5))[0]
    plt.plot(s.wave[xvals], s.flux[xvals]+np.random.random(), color='#0074D9', alpha=0.5)

# %%
no=sf.data[sf.data.spt==27.0].sample(n=10).spectra.apply(plot)

# %%
no=sf.data[sf.data.spt==36.0].sample(n=10).spectra.apply(plot)

# %%
np.log10(6)
# Out:
# 0.7781512503836436

# %%
dfnnn=pd.DataFrame()
dfnnn['snr']=sf.data.snr1.apply(np.log10)
dfnnn['spt']=sf.data.spt
dfnnn['selected']=sf.data.selected

# %%
dfnn=dfnnn[dfnnn.snr.between(-1, 3)]

# %%
fig, ax=plt.subplots(ncols=1, figsize=(12, 4), sharex=False, sharey=True)
dfnn.plot.hexbin(x='snr', y='spt', C='selected', reduce_C_function=np.nanmean, gridsize=20, cmap=wisps.MYCOLORMAP2, ax=ax)

# %%
werd=sf.data[(sf.data.snr1.between(100.0,1000.0)) & (sf.data.selected==1) & (sf.data.spt>35.0)]

# %%
s=werd.spectra.sample(n=1).iloc[0]
splat.classifyByStandard(s.splat_spectrum, plot=True)
# Out:
# ('L9.0', 0.5)

# %%
import wisps
import splat

# %%
t0=splat.getSpectrum(spt='T5')
# Out:
# Retrieving 22 files

# %%
t0[0]
# Out:
# SPEX-PRISM spectrum of WISE J004542.56+361139.1

# %%
s=wisps.Spectrum(wave=t0[0].wave.value, flux=t0[0].flux.value, noise=t0[0].noise.value)

# %%
s.add_noise(2)

# %%
sp.f_test()
# Out:
# spex_chi         410595
# line_chi    1.60663e+06
# spt                T7.0
# f              0.538331
# dtype: object

# %%
sp=s.original

@np.vectorize
@numba.jit
def return_noised_spectrum(snr):
    ##returns a specrtum parameters 
    #after applying noise 
    sp.add_noise(snr)
    return  sp

# %%
# Out:
#          1604373 function calls (1543779 primitive calls) in 1.321 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     16968    0.110    0.000    0.287    0.000 core.py:2085(_expand_and_gather)
#       202    0.061    0.000    1.020    0.005 core.py:306(__init__)
#       202    0.052    0.000    0.052    0.000 core.py:483(<listcomp>)
# 42622/606    0.043    0.000    0.092    0.000 copy.py:132(deepcopy)
#     43026    0.036    0.000    0.056    0.000 core.py:2086(add_unit)
# 87599/83963    0.035    0.000    0.102    0.000 {built-in method builtins.getattr}
#     19089    0.034    0.000    0.346    0.000 core.py:2010(__init__)
#    124641    0.032    0.000    0.035    0.000 {built-in method builtins.isinstance}
#       360    0.031    0.000    0.031    0.000 ffi.py:105(__call__)
# 22018/13938    0.028    0.000    0.172    0.000 core.py:2132(decompose)
# ...

# %%
spts=np.linspace(20, 40)

# %%
spts
# Out:
# array([20.        , 20.40816327, 20.81632653, 21.2244898 , 21.63265306,
#        22.04081633, 22.44897959, 22.85714286, 23.26530612, 23.67346939,
#        24.08163265, 24.48979592, 24.89795918, 25.30612245, 25.71428571,
#        26.12244898, 26.53061224, 26.93877551, 27.34693878, 27.75510204,
#        28.16326531, 28.57142857, 28.97959184, 29.3877551 , 29.79591837,
#        30.20408163, 30.6122449 , 31.02040816, 31.42857143, 31.83673469,
#        32.24489796, 32.65306122, 33.06122449, 33.46938776, 33.87755102,
#        34.28571429, 34.69387755, 35.10204082, 35.51020408, 35.91836735,
#        36.32653061, 36.73469388, 37.14285714, 37.55102041, 37.95918367,
#        38.36734694, 38.7755102 , 39.18367347, 39.59183673, 40.        ])

# %%
ar=np.random.random(size=(len(spts), 4))

# %%
def fast_measure_indices(sp):
    #fast wway to measure indices without monte-carlo sampling or interpolation
    regions=np.array([[[1.15, 1.20], [1.246, 1.295]],
         [[1.38, 1.43],  [1.15, 1.20]], 
         [[1.56, 1.61],  [1.15, 1.20]], 
         [[1.62,1.67],   [1.15, 1.20]], 
        [[1.38, 1.43],  [1.246, 1.295]], 
         [[1.56, 1.61],  [1.246, 1.295]],
         [[1.62,1.67],   [1.246, 1.295]], 
         [[1.56, 1.61],  [1.38, 1.43]],
         [[1.62,1.67],   [1.38, 1.43]],
         [[1.62,1.67],   [1.56, 1.61]]])
    labels=wisps.INDEX_NAMES
    res=pd.Series()
    res.columns=labels
    #loop over ratios 
    for r, l in zip(regions, labels):
        flx1=np.nanmedian(sp.flux[np.where((sp.wave>r[0][0]) & (sp.wave<r[0][1]))[0]])
        flx2=np.nanmedian(sp.flux[np.where((sp.wave>r[1][0]) & (sp.wave<r[1][1]))[0]])
        res[l]= (flx1/flx2, 0.0)
    return dict(res)

# %%
# %prun fast_measure_indices(sp)
# Out:
#          13986 function calls (13780 primitive calls) in 0.028 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.002    0.002    0.028    0.028 <ipython-input-279-921de8f5dee5>:1(fast_measure_indices)
#      2818    0.001    0.000    0.002    0.000 {built-in method builtins.isinstance}
#     42/31    0.001    0.000    0.005    0.000 base.py:255(__new__)
#       234    0.001    0.000    0.001    0.000 {built-in method numpy.core.multiarray.array}
#        10    0.001    0.000    0.018    0.002 indexing.py:298(_setitem_with_indexer)
#       563    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#       738    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#        41    0.001    0.000    0.001    0.000 {pandas._libs.lib.infer_dtype}
#        20    0.000    0.000    0.000    0.000 {method 'partition' of 'numpy.ndarray' objects}
# ...
