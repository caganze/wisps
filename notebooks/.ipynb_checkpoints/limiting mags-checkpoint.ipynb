# %%
import splat
import wisps
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib as mpl
#matplotlib defaults
mpl.rcParams['grid.color'] = 'k'
mpl.rcParams['grid.linestyle'] = '--'
mpl.rcParams['grid.linewidth'] = 0.1
mpl.rcParams['figure.figsize'] = [8.0, 6.0]
mpl.rcParams['figure.dpi'] = 80
mpl.rcParams['savefig.dpi'] = 100
mpl.rcParams['font.size'] = 18
mpl.rcParams['legend.fontsize'] = 'large'
mpl.rcParams['figure.titlesize'] = 'large'



# %matplotlib inline

# %%
#plot mag vs 
obs=pd.read_csv(wisps.OUTPUT_FILES+'/observation_log.csv')
obs.columns=[x.lower() for x in obs.columns]#.lower()
obs.columns
# Out:
# Index(['unnamed: 0', 'ra (deg)', 'dec(deg)', 'l (deg)', 'b (deg)',
#        'exposure (s)', 'observation date (ut)', 'pointing'],
#       dtype='object')

# %%
phot=pd.read_hdf(wisps.COMBINED_PHOTO_SPECTRO_FILE, key='all_phot_spec_data')

# %%
#ignore uncertaints
fphot=wisps.Annotator.reformat_table(phot)

#look at the effect of f_test and snr cut on the limiting magnitude
cutphot=fphot[fphot.snr1>5.0]

# %%
#reported depths by survey
#arragenged as aegis, cosmos, goodsn, goodss, uds
reported_depths={'F110W':[np.nan, np.nan, np.nan, np.nan, np.nan], 
                 'F140W':[25.7, 25.5, 25.9, 25.6, 25.2],
                'F160W':[26.1, 25.8, 26.1, 26.4, 25.9]}

manual_cutoffs={'F110W': [[[6000.0, 22.], [0.0, 17.5]], [[6000.0, 26.3], [0.0, 26.3]]],
                'F140W':[[[2000.0, 22.], [0.0, 12.5]], [[6000.0, 26.1], [0.0, 26.1]]],
               'F160W':[[[6000.0, 22.], [0.0, 17.5]], [[6000.0, 26.5], [0.0, 26.5]]]}

# %%
cutphotwisps=cutphot[cutphot.pointing.apply(lambda x: x.lower().startswith('par'))]
cutphot3dhst=cutphot[cutphot.pointing.apply(lambda x: not x.lower().startswith('par'))]

# %%
fig, axes=plt.subplots(ncols=3, sharex=True, figsize=(12, 4))

for ax, k in zip(axes, manual_cutoffs.keys()):
    print(k)
    pts=np.array(manual_cutoffs[k])
    ax.invert_yaxis()
    ax.grid()
    ax.set_xlabel('exposure (s)', fontsize=18)
    ax.plot(pts[0][:,0], pts[0][:,1], color='#111111')
    ax.plot(pts[1][:,0], pts[1][:,1], color='#111111')
    ax.set_ylabel(k, fontsize=18)
    
    for x in reported_depths[k]: ax.axhline(x, color='#111111', linestyle='--', alpha=0.3)
    
#sns.jointplot(x="exposure", y="F110", data=cutphotwisps, kind="kde", ax=axes[0])
axes[0].scatter( cutphotwisps.exposure, cutphotwisps.F110, s=50,marker=',', alpha=0.01, color='#0074D9')
axes[0].scatter( cutphot3dhst.exposure, cutphot3dhst.F110, s=50,marker=',', alpha=0.01, color='#2ECC40')


axes[1].scatter( cutphotwisps.exposure, cutphotwisps.F140, s=50,marker=',', alpha=0.01, color='#0074D9')
axes[1].scatter( cutphot3dhst.exposure, cutphot3dhst.F140, s=50,marker=',', alpha=0.01, color='#2ECC40')

axes[2].scatter( cutphotwisps.exposure, cutphotwisps.F160, s=50,marker=',', alpha=0.01, color='#0074D9')
axes[2].scatter( cutphot3dhst.exposure, cutphot3dhst.F160, s=50,marker=',', alpha=0.01, color='#2ECC40')
#axes[1].scatter( cutphot.exposure, cutphot.F140, s=50,marker=',', alpha=0.01, color='#0074D9')
#axes[2].scatter( cutphot.exposure, cutphot.F160, s=50,marker=',', alpha=0.01, color='#0074D9')

#axes[1].set_xlim([0, 2000.0])
plt.tight_layout()
plt.savefig(wisps.OUTPUT_FIGURES+'/mag_sensitivity.pdf')
# Out:
# F110W
# F140W
# F160W

# %%
#create polynomail fits 
mag_limits=pd.DataFrame()
for k in  manual_cutoffs.keys():
    vertices=np.array(manual_cutoffs[k])
    bright_p=np.poly1d( np.polyfit(vertices[0][:,0], vertices[0][:,1], 1))
    faint_p=np.poly1d( np.polyfit(vertices[1][:,0], vertices[1][:,1], 1))
    cutphot['bright_'+k]=18.0#bright_p(cutphot.exposure.values)
    cutphot['faint_'+k]=22.0#aint_p(cutphot.exposure.values)
    #cutphot['faint_F110W']=float(26.3)

# %%
np.nanmean(cutphot.faint_F160W), np.nanmean([26.1, 25.8, 26.1, 26.4, 25.9]), np.nanmean(cutphot.faint_F140W), np.nanmean([25.7, 25.5, 25.9, 25.6, 25.2])
# Out:
# (22.0, 26.060000000000002, 22.0, 25.58)

# %%
fig, (ax, ax1)=plt.subplots(ncols=2, sharey=True)
ax.set_yscale('log')
ax.set_ylim([10**-5, 10**5])
ax.scatter(cutphot.F140-cutphot.bright_F140W, abs(cutphot.snr1), s=50,marker=',', alpha=0.009, c='#AAAAAA', label='all')
#ax.scatter( cutphot.F140, abs(cutphot.snr1), s=50,marker=',', alpha=0.1, c='#0074D9', label=r'f > 0.6')
ax.axhline(y=5,  color='#2ECC40')
ax.set_ylabel('SNR', fontsize=16)
ax.set_xlabel('F140W- bright F140W', fontsize=16)

ax1.set_yscale('log')
ax1.set_ylim([10**-5, 10**5])
ax1.axhline(y=5,  color='#2ECC40')
ax1.scatter( cutphot.F140-cutphot.faint_F140W ,abs(cutphot.snr1), s=50,marker=',', alpha=0.1, c='#AAAAAA', label='all')
#ax1.scatter( cutphot.F160, abs(cutphot.snr2), s=50,marker=',', alpha=0.1, c='#0074D9', label=r'f > 0.6')
ax1.set_ylabel('SNR', fontsize=16)
ax1.set_xlabel('F140W - faint F140W', fontsize=16)

ax.grid()
ax1.grid()
plt.legend()
plt.tight_layout()
plt.savefig(wisps.OUTPUT_FIGURES+'/mag_snr.pdf')

# %%
obs=obs.drop_duplicates(subset='pointing')

# %%
#mags_df[mags_df.pointing.str.contains('uds')]

# %%
#obs[obs.pointing.isin(mags_df.pointing)].
mags_df=cutphot[['pointing', 'bright_F110W', 'faint_F110W', 'bright_F140W',
       'faint_F140W', 'bright_F160W', 'faint_F160W']]

#adopt reported magnitudes in at the end/sorry they're all 22
mags_df['faint_F140W'][mags_df.pointing.str.contains('aegis')]=22.0
mags_df['faint_F140W'][mags_df.pointing.str.contains('goodsn')]=22.0
mags_df['faint_F140W'][mags_df.pointing.str.contains('goodss')]=22.0
mags_df['faint_F140W'][mags_df.pointing.str.contains('cosmos')]=22.0
mags_df['faint_F140W'][mags_df.pointing.str.contains('uds')]=22.0
mags_df['faint_F140W'][mags_df.pointing.str.contains('par')]=22.0

mags_df['faint_F160W'][mags_df.pointing.str.contains('aegis')]=22.0
mags_df['faint_F160W'][mags_df.pointing.str.contains('goodsn')]=22.0
mags_df['faint_F160W'][mags_df.pointing.str.contains('goodss')]=22.0
mags_df['faint_F160W'][mags_df.pointing.str.contains('cosmos')]=22.0
mags_df['faint_F160W'][mags_df.pointing.str.contains('uds')]=22.0
mags_df['faint_F110W'][mags_df.pointing.str.contains('par')]=22.0
mags_df['faint_F160W'][mags_df.pointing.str.contains('par')]=22.0



mags_with_limit=mags_df.merge(obs,on='pointing', how='inner', validate='many_to_one').drop_duplicates(subset='pointing').reset_index(drop=True).drop(columns=['unnamed: 0'])
mags_with_limit.to_csv(wisps.OUTPUT_FILES+'//observation_log_with_limit.csv')

# %%
#write indices file for selection criteria
phot[(phot.snr1>5.0) & (phot.f_test>0.6)].to_hdf(wisps.COMBINED_PHOTO_SPECTRO_FILE, key='snr_f_test_cut')

# %%
len(phot[(phot.snr1>5.0) & (phot.f_test>0.5)])
# Out:
# 1679

# %%
made_the_cut=phot[(phot.snr1>1.0) & (phot.f_test>0.6)]

# %%
#mags_df

# %%
fig, axes=plt.subplots(ncols=3, figsize=(14, 6))
cutphot.F160.plot(kind='kde', ax=axes[0], label='F140')
cutphot.F110.plot(kind='kde', ax=axes[1], label='F110')
cutphot.F140.plot(kind='kde', ax=axes[2], label='F140')


for ax, k in zip(axes, manual_cutoffs.keys()):
    print(k)
    pts=np.array(manual_cutoffs[k])
    ax.set_xticks(np.arange(0, 30,2 ))
    ax.grid()
    #ax.set_xlabel('exposure (s)', fontsize=18)
    #ax.plot(pts[0][:,0], pts[0][:,1], color='#111111')
    #ax.plot(pts[1][:,0], pts[1][:,1], color='#111111')
    ax.set_xlabel(k, fontsize=18)
    ax.set_xlim([2, 30])
    
    for x in reported_depths[k]: ax.axvline(x, color='#111111', linestyle='--', alpha=0.3)

axes[0].axvline(22.0, color='#111111')
axes[1].axvline(22.0, color='#111111')
axes[2].axvline(22.0, color='#111111')

plt.tight_layout()
# Out:
# F110W
# F140W
# F160W

# %%
#mags_with_limit.faint_F110W.plot(kind='hist')

# %%
#phot
