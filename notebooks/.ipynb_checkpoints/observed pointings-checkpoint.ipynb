# %%
import wisps
import splat
import wisps.simulations as wispsim
import matplotlib.pyplot as plt
import pandas as pd
import astropy.units as u
from astropy.coordinates import SkyCoord
# %matplotlib inline

# %%
lf=wispsim.LUMINOSITY_FUCTION
lfdes=wispsim.DES_LUMINOSITY_FUCTION
maglimits=wispsim.MAG_LIMITS

# %%
from wisps.simulations import Pointing

# %%
obs=pd.read_csv(wisps.OUTPUT_FILES+'//observation_log_with_limit.csv')

# %%
obs.columns
# Out:
# Index(['Unnamed: 0', 'pointing', 'bright_F110W', 'faint_F110W', 'bright_F140W',
#        'faint_F140W', 'bright_F160W', 'faint_F160W', 'ra (deg)', 'dec(deg)',
#        'l (deg)', 'b (deg)', 'exposure (s)', 'observation date (ut)'],
#       dtype='object')

# %%
def make_pointing(ra, dec, survey, name):
    coord=SkyCoord(ra=ra*u.deg,dec=dec*u.deg )
    return Pointing(coord=coord, survey=survey, name=name)

# %%
def get_survey(pointing):
    if pointing.startswith('par'):
        return 'wisps'
    else:
        return 'hst3d'

# %%
ras=obs['ra (deg)']
decs=obs['dec(deg)']
surveys=obs.pointing.apply(get_survey)

# %%
pnts=[make_pointing(ra, dec, survey, name) for ra, dec, survey, name in zip(ras, decs, surveys, obs.pointing.values)]

# %%
for pnt in pnts:
    pnt.mag_limits=maglimits[pnt.survey]
    #print( pnt.survey)
    pnt.compute_distance_limits()
# Out:
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# wisps
# hst3d
# hst3d
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-54cf7c5df708> in <module>
#       2     pnt.mag_limits=maglimits[pnt.survey]
#       3     print( pnt.survey)
# ----> 4     pnt.compute_distance_limits()
#
# ~/research/wisps/wisps/simulations/core.py in compute_distance_limits(self)
#     134
#     135             #compute asbmags using abolute mag relations
# --> 136             absmags=pol(spgrid)
#     137             relfaintmags=np.array([maglmts[0] for s in spgrid])
#     138             relbrightmags=np.array([maglmts[1] for s in spgrid])
#
# TypeError: 'NoneType' object is not callable

# %%
import pickle
#save the random forest
output_file=wisps.OUTPUT_FILES+'/observed_pointings.pkl'
with open(output_file, 'wb') as file:
    pickle.dump(pnts,file)

# %%
import numpy as np

# %%
spgrid=np.arange(20, 38)

# %%
#dict(zip(spgrid, spgrid))
