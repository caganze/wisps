# %% [markdown]
# Midterm goal: finish with the data analysis
#
# Play with different classes of contaminants, see why they fall where they fall
#
# → start with a sample of ~300 sources, see if you need to modify your indices

# %%
import wisps
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
from wisps.data_analysis import selection_criteria as sel_crt
% matplotlib inline

# %%
#load selection criteria
crts=sel_crt.crts_from_file()

# %%
#load the selector object
selector=wisps.Selector()

# %%
best_crts=['H-cont/J-Cont H_2O-2/J-Cont', 
           'CH_4/H-Cont H_2O-2/J-Cont',
           'CH_4/H-Cont H-cont/J-Cont']

# %%
best=[crts[x] for x in best_crts]

# %%
#see which M7-L0 are selected in all these criteria
#slctd=selector.select('T5-T9', [x for x in best], df, logic='and')

# %%
selected=[['a'], ['a', 'b'], ['a', 'b', 'c'], ['a', 'b', 'c', 'd', 'e']]
set().union(*selected)
# Out:
# {'a', 'b', 'c', 'd', 'e'}

# %%
list(set.intersection(*map(set,selected)))
# Out:
# ['a']

# %%
[x.plot(figsize=(6,6), highlight=['T5-T9']) for x in best]
# Out:
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# [None, None, None]

# %%
df=wisps.COMBINED_PHOTO_SPECTRO_DATA.rename(columns={'grism_id': 'Names'})

# %%
#best

# %%
dflist=[]
for c in best:
    sl1=c.select(df, shapes_to_use=['T5-T9'])
    dflist.append(pd.concat([df[df.Names.isin(x)] for x in sl1]))

# %%
import functools
t_dwarfs=functools.reduce(lambda x, y: pd.merge(x, y, how = 'inner', on='Names'), dflist)

# %%
t_dwarfs.Names.values
# Out:
# array(['aegis-03-G141_17053', 'goodsn-15-G141_25392',
#        'goodsn-44-G141_10917', 'goodss-35-G141_46811', 'Par36_BEAM_119A',
#        'Par44_BEAM_391A', 'Par45_BEAM_223A', 'Par138_BEAM_60A',
#        'Par154_BEAM_204A', 'Par166_BEAM_221A', 'Par176_BEAM_74A',
#        'Par245_BEAM_54A', 'Par330_BEAM_1067A'], dtype=object)

# %%
def plot(name):
    sp=wisps.Source(name=name, save=True)
    sp.plot()

# %%
#t_dwarfs.Names.apply(plot)

# %%
for c in crts.values():
    print (c.name)
    c.plot(save=True, figsize=(6,6))
# Out:
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
# selfcolor none
